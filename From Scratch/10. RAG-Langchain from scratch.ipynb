# %%
'''
Title: RAG /LANGCHAIN / vector spaces
Author:
Date:
Description:
to_deploy: No
------------------------------------------------------------------------------------------------------------------------------------
------------------------------------------------------------------------------------------------------------------------------------
References:
https://github.com/langchain-ai/rag-from-scratch

'''
