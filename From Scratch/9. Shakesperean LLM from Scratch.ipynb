# %%
'''
Title: Building NanoGPT and Shakesperean GPT
Author: Liana Poghosyan, Siddharth Sharma, Andrej*
Date:
Description: Following the vedio of Andrej, our main motive is to makea GPT model which is trained on Shakeperean dataset. This model is intended to be deployed with the help of Streamlit.
To_Deploy: Yes

References and Credits:
https://www.youtube.com/watch?v=kCc8FmEb1nY {To Follow}
Book / Reading:
https://github.com/ManalAbumelhaa/LLM-LLMs-from-scratch


# More referernces:
https://www.youtube.com/playlist?list=PLAqhIrjkxbuWI23v9cThsA9GvCAUhRvKZ

'''
