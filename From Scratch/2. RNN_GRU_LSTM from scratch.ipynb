# %%
'''
-----------------------------------------------------------------------------------------------------------------------------------------------------
-----------------------------------------------------------------------------------------------------------------------------------------------------
Author: Siddharth Sharma, liana Poghosyan
Date: 2024-07-19
-----------------------------------------------------------------------------------------------------------------------------------------------------
-----------------------------------------------------------------------------------------------------------------------------------------------------
References and Credits:
https://github.com/kaustubhhiware/LSTM-GRU-from-scratch (MIT LISCEnse at the time of referencing) -- Permission Granted.
Multilayer - RNN from Scratch: https://medium.com/@yash9439/building-multi-layer-rnn-from-scratch-d0d8e0e9aaf5
Multilayer - GRU from Scratch: https://medium.com/@yash9439/building-multi-layer-gru-from-scratch-305a03670fdd
Multilayer - LSTM from Scratch: https://medium.com/@yash9439/building-multi-layer-lstm-from-scratch-290b1254f1e1

'''
